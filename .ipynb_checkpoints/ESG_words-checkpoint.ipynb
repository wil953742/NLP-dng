# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./BaierBerningerKiesel_ESG-Wordlist_2020.csv')
print(data)
# Out:
#            Word       Topic              Category        Subcategory
# 0      approval  Governance  Corporate Governance  Audit and control
# 1     approvals  Governance  Corporate Governance  Audit and control
# 2       approve  Governance  Corporate Governance  Audit and control
# 3      approved  Governance  Corporate Governance  Audit and control
# 4      approves  Governance  Corporate Governance  Audit and control
# ...         ...         ...                   ...                ...
# 1209        NaN         NaN                   NaN                NaN
# 1210        NaN         NaN                   NaN                NaN
# 1211        NaN         NaN                   NaN                NaN
# 1212        NaN         NaN                   NaN                NaN
# 1213        NaN         NaN                   NaN                NaN
#
# [1214 rows x 4 columns]

# %%
data.columns
# Out:
# Index(['Word', 'Topic', 'Category', 'Subcategory'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1214, step=1)

# %%
data.describe()
# Out:
#             Word       Topic              Category Subcategory
# count        482         482                   482         482
# unique       482           3                    11          35
# top     approval  Governance  Corporate Governance           -
# freq           1         276                   194         118

# %%
import tweepy

def connect_api():

    consumer_key = 'ydEFxTpESTRwGNlMJqKudfYX4'
    consumer_secret = 'xZR31KA7SmBdvXpBKPW7hPlYfnRPyX5t4mfKkPaKoIqPcg3xXb'
    access_token = '1520349885190766592-3lWYnaAsQLojqmCbuD74WRg5iivF1n'
    access_token_secret = 'Hs73OKbUnGH9bGLz9OA3JcVa9hdWKf6z81gvHINvpoyQC'

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    api = tweepy.API(auth)

    return api

print(connect_api())
# Out:
# <tweepy.api.API object at 0x7f8de434da60>

# %%
def get_tweets(api, username):
    tweets = api.user_timeline(screen_name=username, tweet_mode='extended')

    return tweets

api = connect_api()
bts_timeline = get_tweets(api, 'bts_official')
print(bts_timeline)
# Out:
# [Status(_api=<tweepy.api.API object at 0x7f8de3cade80>, _json={'created_at': 'Sun Oct 18 18:05:22 +0000 2009', 'id': 4970613281, 'id_str': '4970613281', 'full_text': 'i was banned from this website /: ---&gt; http://www.jonasbrothersfanfictionarchive.com/index.php', 'truncated': False, 'display_text_range': [0, 97], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 50368705, 'id_str': '50368705', 'name': 'Heather Jonas', 'screen_name': 'bts_official', 'location': 'Nashville', 'description': 'This Twitter Account is the Official Twitter for -blursthesane;', 'url': 'http://t.co/14gxOHCNIJ', 'entities': {'url': {'urls': [{'url': 'http://t.co/14gxOHCNIJ', 'expanded_url': 'http://www.myspace.com/hollister600', 'display_url': 'myspace.com/hollister600', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 470, 'friends_count': 14, 'listed_count': 0, 'created_at': 'Wed Jun 24 17:19:15 +0000 2009', 'favourites_count': 5, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 43, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0099B9', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/476795043/BTS_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/476795043/BTS_normal.png', 'profile_link_color': '0099B9', 'profile_sidebar_border_color': '5ED4DC', 'profile_sidebar_fill_color': '95E8EC', 'profile_text_color': '3C3940', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 7, 'favorite_count': 21, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2009, 10, 18, 18, 5, 22, tzinfo=datetime.timezone.utc), id=4970613281, id_str='4970613281', full_text='i was banned from this website /: ---&gt; http://www.jonasbrothersfanfictionarchive.com/index.php', truncated=False, display_text_range=[0, 97], entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web Client', source_url='http://twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7f8de3cade80>, _json={'id': 50368705, 'id_str': '50368705', 'name': 'Heather Jonas', 'screen_name': 'bts_official', 'location': 'Nashville', 'description': 'This Twitter Account is the Official Twitter for -blursthesane;', 'url': 'http://t.co/14gxOHCNIJ', 'entities': {'url': {'urls': [{'url': 'http://t.co/14gxOHCNIJ', 'expanded_url': 'http://www.myspace.com/hollister600', 'display_url': 'myspace.com/hollister600', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 470, 'friends_count': 14, 'listed_count': 0, 'created_at': 'Wed Jun 24 17:19:15 +0000 2009', 'favourites_count': 5, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 43, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '0099B9', 'profile_background_image_url': 'http://abs.twimg.c ...

# %%
api = connect_api()
bts_timeline = get_tweets(api, 'bts_official')
i=1

for bts_tweet in bts_timeline:
    print(f"{i}번째 트윗 : {bts_tweet.full_text}")
    i += 1
# Out:
# 1번째 트윗 : i was banned from this website /: ---&gt; http://www.jonasbrothersfanfictionarchive.com/index.php
# 2번째 트윗 : http://bit.ly/1MnAyr &lt;---click that. &lt;3
# 3번째 트윗 : new profile picture. &lt;3
# 4번째 트윗 : @DirtyJBThoughts i agree with you. /: - i could talk perverted about them alllll day. ;D
# 5번째 트윗 : @Jonasbrothers HAPPY BIRTHDAY, FRANKIE! i loveee youuu, &lt;3
# 6번째 트윗 : @Jonasbrothers Joe- "Who has the bigger muscles; me or Nick?" HMM- DEFINETELYJOSEPH! ;D
# 7번째 트윗 : @Tiffdizzlejonas tiffdizzlejonas. WEEOW. i loveee it! - Heather. (':
# 8번째 트윗 : don't even ask...
# 9번째 트윗 : meow.
# 10번째 트윗 : ahhh. i changed my name, again.
# 11번째 트윗 : well, i didn't have to change accounts after all. :D
# 12번째 트윗 : i might have to move this twitter to a different account because i changed my site name to -hollywoodwhore;
# 13번째 트윗 : @Jonasbrothers whatt thee heckk, ? :'D
# 14번째 트윗 : @ddlovato i didn't even know,
# 15번째 트윗 : dood. - i think somebody hacked my Jonas Brothers siteee,
# 16번째 트윗 : add my site, http://www.myspace.com/hollister600
# 17번째 트윗 : likee the new pictureee, ?
# 18번째 트윗 : going to change my profile pirctureee,
# 19번째 트윗 : danggg, i havent been on this thannyy in a longg time.
# 20번째 트윗 : @ddlovato omj, tell me why.
