# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./BaierBerningerKiesel_ESG-Wordlist_2020.csv')

df = df.dropna()
for word in df['Word']:
    print(word)
# Out:
# approval
# approvals
# approve
# approved
# approves
# approving
# assess
# assessed
# assesses
# assessing
# assessment
# assessments
# audit
# audited
# auditing
# auditor
# auditors
# audits
# control
# controls
# coso
# detect
# detected
# detecting
# detection
# evaluate
# evaluated
# evaluates
# evaluating
# evaluation
# evaluations
# examination
# examinations
# examine
# examined
# examines
# examining
# irs
# oversee
# overseeing
# oversees
# oversight
# review
# reviewed
# reviewing
# reviews
# rotation
# test
# tested
# testing
# tests
# treadway
# backgrounds
# independence
# leadership
# nomination
# nominations
# nominee
# nominees
# perspectives
# qualifications
# refreshment
# skill
# skills
# succession
# tenure
# vacancies
# vacancy
# appreciation
# award
# awarded
# awarding
# awards
# bonus
# bonuses
# cd
# compensate
# compensated
# compensates
# compensating
# compensation
# eip
# iso
# isos
# payout
# payouts
# pension
# prsu
# prsus
# recoupment
# ...

# %%
df = pd.read_csv('./BaierBerningerKiesel_ESG-Wordlist_2020.csv')
df = df.dropna()
word_list = [ word.strip() for word in df['Word']]

# %%
for word in word_list:
    print(word)
    
# 소문자로 통일한다. un 같은 경우는? test와 같은 중의어는?
# 단어의 길이가 너무 짧은 단어들을 삭제? 2개짜리 단어가 몇개 있으니까 un, cd, ms
# Out:
# approval
# approvals
# approve
# approved
# approves
# approving
# assess
# assessed
# assesses
# assessing
# assessment
# assessments
# audit
# audited
# auditing
# auditor
# auditors
# audits
# control
# controls
# coso
# detect
# detected
# detecting
# detection
# evaluate
# evaluated
# evaluates
# evaluating
# evaluation
# evaluations
# examination
# examinations
# examine
# examined
# examines
# examining
# irs
# oversee
# overseeing
# oversees
# oversight
# review
# reviewed
# reviewing
# reviews
# rotation
# test
# tested
# testing
# tests
# treadway
# backgrounds
# independence
# leadership
# nomination
# nominations
# nominee
# nominees
# perspectives
# qualifications
# refreshment
# skill
# skills
# succession
# tenure
# vacancies
# vacancy
# appreciation
# award
# awarded
# awarding
# awards
# bonus
# bonuses
# cd
# compensate
# compensated
# compensates
# compensating
# compensation
# eip
# iso
# isos
# payout
# payouts
# pension
# prsu
# prsus
# recoupment
# ...

# %%
df[df['Topic'] == 'Governance']
# Out:
#               Word       Topic                                 Category  \
# 0         approval  Governance                     Corporate Governance
# 1        approvals  Governance                     Corporate Governance
# 2          approve  Governance                     Corporate Governance
# 3         approved  Governance                     Corporate Governance
# 4         approves  Governance                     Corporate Governance
# ..             ...         ...                                      ...
# 271      relations  Governance  Sustainability Management and Reporting
# 272    stakeholder  Governance  Sustainability Management and Reporting
# 273   stakeholders  Governance  Sustainability Management and Reporting
# 274        compact  Governance  Sustainability Management and Reporting
# 275           ungc  Governance  Sustainability Management and Reporting
#
#                 Subcategory
# 0         Audit and control
# 1         Audit and control
# ...

# %%
df.groupby(['Topic']).count()
# Out:
#                Word  Category  Subcategory
# Topic
# Environmental    55        55           55
# Governance      276       276          276
# Social          151       151          151

# %%
df.groupby(['Category']).count()
# Out:
#                                          Word  Topic  Subcategory
# Category
# -                                          31     31           31
# Business Ethics                            22     22           22
# Climate Change                             16     16           16
# Corporate Governance                      194    194          194
# Ecosystem Service                          13     13           13
# Environmental Management                   22     22           22
# Human Rights                               16     16           16
# Labor Standards                            48     48           48
# Public Health                              25     25           25
# Society                                    49     49           49
# Sustainability Management and Reporting    46     46           46

# %%
df[df['Category'] == 'Business Ethics'].groupby('Topic').count()
# Out:
#             Word  Category  Subcategory
# Topic
# Governance    22        22           22

# %%
df[df['Category'] == 'Climate Change'].groupby('Topic').count()
# Out:
#                Word  Category  Subcategory
# Topic
# Environmental    16        16           16

# %%
df[df['Category'] == 'Corporate Governance'].groupby('Topic').count()
# Out:
#             Word  Category  Subcategory
# Topic
# Governance   194       194          194

# %%
df[df['Category'] == 'Ecosystem Service'].groupby('Topic').count()
# Out:
#                Word  Category  Subcategory
# Topic
# Environmental    13        13           13

# %%
df[df['Category'] == 'Environmental Management'].groupby('Topic').count()
# Out:
#                Word  Category  Subcategory
# Topic
# Environmental    22        22           22

# %%
df[df['Category'] == 'Human Rights'].groupby('Topic').count()
# Out:
#         Word  Category  Subcategory
# Topic
# Social    16        16           16

# %%
df[df['Category'] == 'Labor Standards'].groupby('Topic').count()
# Out:
#         Word  Category  Subcategory
# Topic
# Social    48        48           48

# %%
df[df['Category'] == 'Public Health'].groupby('Topic').count()
# Out:
#         Word  Category  Subcategory
# Topic
# Social    25        25           25

# %%
df[df['Category'] == 'Society'].groupby('Topic').count()
# Out:
#         Word  Category  Subcategory
# Topic
# Social    49        49           49

# %%
df[df['Category'] == 'Sustainability Management and Reporting'].groupby('Topic').count()
# Out:
#             Word  Category  Subcategory
# Topic
# Governance    46        46           46

# %%
import tweepy

def connect_api():

    consumer_key = 'ydEFxTpESTRwGNlMJqKudfYX4'
    consumer_secret = 'xZR31KA7SmBdvXpBKPW7hPlYfnRPyX5t4mfKkPaKoIqPcg3xXb'
    access_token = '1520349885190766592-3lWYnaAsQLojqmCbuD74WRg5iivF1n'
    access_token_secret = 'Hs73OKbUnGH9bGLz9OA3JcVa9hdWKf6z81gvHINvpoyQC'

    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)

    api = tweepy.API(auth)

    return api

print(connect_api())

# %%
def get_tweets(api, username):
    tweets = api.user_timeline(screen_name=username, tweet_mode='extended')

    return tweets

api = connect_api()
bts_timeline = get_tweets(api, 'microsoft')
print(bts_timeline)
# Out:
# [Status(_api=<tweepy.api.API object at 0x7fcf09729910>, _json={'created_at': 'Thu May 05 00:10:48 +0000 2022', 'id': 1522005857713721346, 'id_str': '1522005857713721346', 'full_text': '@RealMeepdude212 One does not easily forget Minesweeper.', 'truncated': False, 'display_text_range': [17, 56], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'RealMeepdude212', 'name': 'RealMeepdude212', 'id': 896207883330650112, 'id_str': '896207883330650112', 'indices': [0, 16]}], 'urls': []}, 'source': '<a href="https://prod1.sprinklr.com" rel="nofollow">Sprinklr Publishing</a>', 'in_reply_to_status_id': 1521964904025968640, 'in_reply_to_status_id_str': '1521964904025968640', 'in_reply_to_user_id': 896207883330650112, 'in_reply_to_user_id_str': '896207883330650112', 'in_reply_to_screen_name': 'RealMeepdude212', 'user': {'id': 74286565, 'id_str': '74286565', 'name': 'Microsoft', 'screen_name': 'Microsoft', 'location': 'Redmond, WA', 'description': "We're on a mission to
# ...

# %%
api = connect_api()
bts_timeline = get_tweets(api, 'bts_official')
i=1

for bts_tweet in bts_timeline:
    print(f"{i}번째 트윗 : {bts_tweet.full_text}")
    i += 1
# Out:
# 1번째 트윗 : i was banned from this website /: ---&gt; http://www.jonasbrothersfanfictionarchive.com/index.php
# 2번째 트윗 : http://bit.ly/1MnAyr &lt;---click that. &lt;3
# 3번째 트윗 : new profile picture. &lt;3
# 4번째 트윗 : @DirtyJBThoughts i agree with you. /: - i could talk perverted about them alllll day. ;D
# 5번째 트윗 : @Jonasbrothers HAPPY BIRTHDAY, FRANKIE! i loveee youuu, &lt;3
# 6번째 트윗 : @Jonasbrothers Joe- "Who has the bigger muscles; me or Nick?" HMM- DEFINETELYJOSEPH! ;D
# 7번째 트윗 : @Tiffdizzlejonas tiffdizzlejonas. WEEOW. i loveee it! - Heather. (':
# 8번째 트윗 : don't even ask...
# 9번째 트윗 : meow.
# 10번째 트윗 : ahhh. i changed my name, again.
# 11번째 트윗 : well, i didn't have to change accounts after all. :D
# 12번째 트윗 : i might have to move this twitter to a different account because i changed my site name to -hollywoodwhore;
# 13번째 트윗 : @Jonasbrothers whatt thee heckk, ? :'D
# 14번째 트윗 : @ddlovato i didn't even know,
# 15번째 트윗 : dood. - i think somebody hacked my Jonas Brothers siteee,
# ...
